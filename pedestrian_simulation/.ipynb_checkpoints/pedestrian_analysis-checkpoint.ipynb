# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../..'))

import reinforcement_learning as rl

# %%
env = rl.TextEnvironment(
    text=   " #####XXX#########XXX#########XXX##### \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            "##           #           #           ##\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "#S                                   S#\n" +
            "##                                   ##\n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #           #           #           # \n" +
            " #####XXX#########XXX#########XXX##### \n",
    max_steps=100,
    neighbor=rl.TextNeighbor.MOORE,
    raw_state=True
)

# %%
single_train_session = rl.SingleTrainSession(env, start_step=20)

# %%
for _ in range(200):
    agent = rl.SarsaLambdaAgent(
            alpha=0.1,
            epsilon=0.3,
            gamma=0.99,
            lambd=0.98,
            epsilon_decay=0.99,
            trace_type="replacing",
            feature_dims=2,
            num_tilings=4,
            tiles_size=[4,4],
        )
    single_train_session.add_agent(agent)

# %%
results = single_train_session.run(500, 50, 50)
results
# Out:
#   6%|▌         | 28/500 [03:22<56:48,  7.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-6f7f4c068b5a> in <module>
# ----> 1 results = single_train_session.run(500, 50, 50)
#       2 results
#
# ~/reinforcementlearninglibrary/reinforcement_learning/sessions/session.py in run(self, episodes, test_offset, test_samples, render, heatmap)
#      34         out = []
#      35         for episode in tqdm(range(1, episodes + 1)):
# ---> 36             self._run_train()
#      37             if episode % test_offset == 0:
#      38                 out.append(
#
# ~/reinforcementlearninglibrary/reinforcement_learning/sessions/single_train_session.py in _run_train(self)
#      19             agent.reset(self._env, id=key)
#      20             while not done:
# ---> 21                 next_state, reward, done, info = agent.run_step(
#      22                     self._env, id=key, mode='train', t=step
#      23                 )
#
# ~/reinforcementlearninglibrary/reinforcement_learning/agents/approximate_agents/eligibility_traces/sarsa_lambda.py in run_step(self, env, *args, **kwargs)
#      52
#      53     def run_step(self, env: Environment, *args, **kwargs) -> Tuple:
# ---> 54         n_S, R, self._episode_ended, info = env.run_step(self._A, **kwargs)
#      55
#      56         if self._episode_ended and not kwargs['mode'] == "test":
#
# ~/reinforcementlearninglibrary/reinforcement_learning/environments/text/text.py in run_step(self, action, *args, **kwargs)
#     203             l = action > 4
#     204             # Update next state, N -> [-1, 0], NE -> [-1, +1], ...
# --> 205             next_state[0] += (-1) ** j * i
#     206             next_state[1] += (-1) ** l * k
#     207         # Check if next state is valid
#
# KeyboardInterrupt:

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance'], axis=1).groupby(['test', 'sample', 'agent'])
arrival_time = groupby.max()
travelling_time = arrival_time - groupby.min()

# %%
arrival_time
# Out:
#                                                                 step
# test sample agent
# 1    0      ID: 139664544683344, Params: Sarsa Lambda: alph...    70
#             ID: 139664544684640, Params: Sarsa Lambda: alph...    99
#             ID: 139664544685936, Params: Sarsa Lambda: alph...   100
#             ID: 139664544711872, Params: Sarsa Lambda: alph...   102
#             ID: 139664544713168, Params: Sarsa Lambda: alph...    99
# ...                                                              ...
# 10   49     ID: 139664544785024, Params: Sarsa Lambda: alph...    49
#             ID: 139664544786320, Params: Sarsa Lambda: alph...    37
#             ID: 139664659816656, Params: Sarsa Lambda: alph...    31
#             ID: 139665918432016, Params: Sarsa Lambda: alph...    38
#             ID: 139665977511360, Params: Sarsa Lambda: alph...    35
#
# [9980 rows x 1 columns]

# %%
travelling_time
# Out:
#                                                                 step
# test sample agent
# 1    0      ID: 139664544683344, Params: Sarsa Lambda: alph...    67
#             ID: 139664544684640, Params: Sarsa Lambda: alph...    99
#             ID: 139664544685936, Params: Sarsa Lambda: alph...    99
#             ID: 139664544711872, Params: Sarsa Lambda: alph...    99
#             ID: 139664544713168, Params: Sarsa Lambda: alph...    99
# ...                                                              ...
# 10   49     ID: 139664544785024, Params: Sarsa Lambda: alph...    46
#             ID: 139664544786320, Params: Sarsa Lambda: alph...    37
#             ID: 139664659816656, Params: Sarsa Lambda: alph...    31
#             ID: 139665918432016, Params: Sarsa Lambda: alph...    37
#             ID: 139665977511360, Params: Sarsa Lambda: alph...    33
#
# [9980 rows x 1 columns]

# %%
arrival_time.loc[(10)]
# Out:
#                                                            step
# sample agent
# 0      ID: 139664544683344, Params: Sarsa Lambda: alph...    43
#        ID: 139664544684640, Params: Sarsa Lambda: alph...    53
#        ID: 139664544685936, Params: Sarsa Lambda: alph...    33
#        ID: 139664544711872, Params: Sarsa Lambda: alph...    29
#        ID: 139664544713168, Params: Sarsa Lambda: alph...    49
# ...                                                         ...
# 49     ID: 139664544785024, Params: Sarsa Lambda: alph...    49
#        ID: 139664544786320, Params: Sarsa Lambda: alph...    37
#        ID: 139664659816656, Params: Sarsa Lambda: alph...    31
#        ID: 139665918432016, Params: Sarsa Lambda: alph...    38
#        ID: 139665977511360, Params: Sarsa Lambda: alph...    35
#
# [1000 rows x 1 columns]

# %%
travelling_time.loc[(10)]
# Out:
#                                                            step
# sample agent
# 0      ID: 139664544683344, Params: Sarsa Lambda: alph...    40
#        ID: 139664544684640, Params: Sarsa Lambda: alph...    50
#        ID: 139664544685936, Params: Sarsa Lambda: alph...    32
#        ID: 139664544711872, Params: Sarsa Lambda: alph...    29
#        ID: 139664544713168, Params: Sarsa Lambda: alph...    47
# ...                                                         ...
# 49     ID: 139664544785024, Params: Sarsa Lambda: alph...    46
#        ID: 139664544786320, Params: Sarsa Lambda: alph...    37
#        ID: 139664659816656, Params: Sarsa Lambda: alph...    31
#        ID: 139665918432016, Params: Sarsa Lambda: alph...    37
#        ID: 139665977511360, Params: Sarsa Lambda: alph...    33
#
# [1000 rows x 1 columns]

# %%
import pandas as pd
scatter = pd.concat([arrival_time, travelling_time], axis=1, sort=False)
scatter.columns = ['arrival_time', 'travelling_time']
scatter
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-8ed77f1c2bc2> in <module>
#       1 import pandas as pd
#       2 pointer = (-1)
# ----> 3 scatter = pd.concat([arrival_time.loc[pointer], travelling_time.loc[pointer]], axis=1, sort=False)
#       4 scatter.columns = ['arrival_time', 'travelling_time']
#       5 scatter
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3533         index = self.index
#    3534         if isinstance(index, MultiIndex):
# -> 3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
#    3537             loc = self.index.get_loc(key)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2844                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    2845         else:
# -> 2846             indexer = self._get_level_indexer(key, level=level)
#    2847             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    2848
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2927         else:
#    2928
# -> 2929             code = self._get_loc_single_level_index(level_index, key)
#    2930
#    2931             if level > 0 or self.lexsort_depth == 0:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2596             return -1
#    2597         else:
# -> 2598             return level_index.get_loc(key)
#    2599
#    2600     def get_loc(self, key, method=None):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1

# %%
points = [
    tuple(row)
    for _, row in scatter.iterrows()
]
points[:10]
# Out:
# [(43, 40),
#  (53, 50),
#  (33, 32),
#  (29, 29),
#  (49, 47),
#  (33, 32),
#  (41, 38),
#  (41, 40),
#  (44, 41),
#  (45, 44)]

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
plt.scatter([p[0] for p in points], [p[1] for p in points])
