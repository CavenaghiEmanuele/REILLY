# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

import reinforcement_learning as rl

# %%
env = rl.TextEnvironment(
    text="##########XXXXXX###\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "###  ##  #####  ###\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "##########SSSSSS###",
    max_steps=100,
    neighbor=rl.TextNeighbor.MOORE,
    raw_state=True
)

# %%
single_train_session = rl.SingleTrainSession(env, start_step=15)

# %%
for _ in range(46):
    #"""
    agent = rl.SarsaLambdaAgent(
            alpha=0.1,
            epsilon=0.3,
            gamma=0.99,
            lambd=0.98,
            epsilon_decay=0.99,
            trace_type="replacing",
            feature_dims=2,
            num_tilings=4,
            tiles_size=[4,4],
        )
    """
    agent = rl.SarsaAgent(
            states=env.states,
            actions=env.actions,
            alpha=0.1,
            epsilon=0.3,
            gamma=0.99,
            epsilon_decay=0.99,
        )
    """
    single_train_session.add_agent(agent)

# %%
results = single_train_session.run(500, 50, 50)
results
# Out:
# 100%|██████████| 500/500 [17:13<00:00,  2.07s/it]
#        test  sample  step                                              agent  \
# 0         1       0     0  ID: 139930672647328, Params: Sarsa Lambda: alp...
# 1         1       0     0  ID: 139930673029616, Params: Sarsa Lambda: alp...
# 2         1       0     1  ID: 139930672647328, Params: Sarsa Lambda: alp...
# 3         1       0     1  ID: 139930672987728, Params: Sarsa Lambda: alp...
# 4         1       0     1  ID: 139930673029616, Params: Sarsa Lambda: alp...
# ...     ...     ...   ...                                                ...
# 85665    10      49    73  ID: 139930673014672, Params: Sarsa Lambda: alp...
# 85666    10      49    74  ID: 139930672987728, Params: Sarsa Lambda: alp...
# 85667    10      49    74  ID: 139930673014672, Params: Sarsa Lambda: alp...
# 85668    10      49    75  ID: 139930673014672, Params: Sarsa Lambda: alp...
# 85669    10      49    75  ID: 139930672987728, Params: Sarsa Lambda: alp...
#
#        return_sum  wins  time  distance
# 0              -1     0  0.25  0.000000
# 1              -1     0  0.25  0.565685
# 2              -1     0  0.25  0.400000
# 3              -1     0  0.25  0.400000
# 4              -1     0  0.25  0.565685
# ...           ...   ...   ...       ...
# 85665          -1     0  0.25  0.565685
# 85666          -1     0  0.25  0.400000
# 85667          -1     0  0.25  0.565685
# 85668          20     1  0.25  0.565685
# 85669          20     1  0.25  0.400000
#
# [1634781 rows x 8 columns]

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance'], axis=1).groupby(['test', 'sample', 'agent'])
arrival_time = groupby.max()
travelling_time = arrival_time - groupby.min()

# %%
arrival_time
# Out:
#                                                                 step
# test sample agent
# 1    0      ID: 139930672591920, Params: Sarsa Lambda: alph...   101
#             ID: 139930672593216, Params: Sarsa Lambda: alph...   109
#             ID: 139930672594512, Params: Sarsa Lambda: alph...   114
#             ID: 139930672608160, Params: Sarsa Lambda: alph...   117
#             ID: 139930672609456, Params: Sarsa Lambda: alph...   113
# ...                                                              ...
# 10   49     ID: 139930673099968, Params: Sarsa Lambda: alph...    29
#             ID: 139930673101264, Params: Sarsa Lambda: alph...    41
#             ID: 139930673102560, Params: Sarsa Lambda: alph...    70
#             ID: 139932055107040, Params: Sarsa Lambda: alph...    35
#             ID: 139932055107472, Params: Sarsa Lambda: alph...    42
#
# [19228 rows x 1 columns]

# %%
travelling_time
# Out:
#                                                                 step
# test sample agent
# 1    0      ID: 139930672591920, Params: Sarsa Lambda: alph...    99
#             ID: 139930672593216, Params: Sarsa Lambda: alph...    99
#             ID: 139930672594512, Params: Sarsa Lambda: alph...    99
#             ID: 139930672608160, Params: Sarsa Lambda: alph...    99
#             ID: 139930672609456, Params: Sarsa Lambda: alph...    99
# ...                                                              ...
# 10   49     ID: 139930673099968, Params: Sarsa Lambda: alph...    29
#             ID: 139930673101264, Params: Sarsa Lambda: alph...    32
#             ID: 139930673102560, Params: Sarsa Lambda: alph...    48
#             ID: 139932055107040, Params: Sarsa Lambda: alph...    31
#             ID: 139932055107472, Params: Sarsa Lambda: alph...    30
#
# [19228 rows x 1 columns]

# %%
arrival_time.loc[(10)]
# Out:
#                                                            step
# sample agent
# 0      ID: 139930672591920, Params: Sarsa Lambda: alph...    30
#        ID: 139930672593216, Params: Sarsa Lambda: alph...    65
#        ID: 139930672594512, Params: Sarsa Lambda: alph...    42
#        ID: 139930672608160, Params: Sarsa Lambda: alph...    48
#        ID: 139930672609456, Params: Sarsa Lambda: alph...    62
# ...                                                         ...
# 49     ID: 139930673099968, Params: Sarsa Lambda: alph...    29
#        ID: 139930673101264, Params: Sarsa Lambda: alph...    41
#        ID: 139930673102560, Params: Sarsa Lambda: alph...    70
#        ID: 139932055107040, Params: Sarsa Lambda: alph...    35
#        ID: 139932055107472, Params: Sarsa Lambda: alph...    42
#
# [1932 rows x 1 columns]

# %%
travelling_time.loc[(10)]
# Out:
#                                                            step
# sample agent
# 0      ID: 139930672591920, Params: Sarsa Lambda: alph...    30
#        ID: 139930672593216, Params: Sarsa Lambda: alph...    47
#        ID: 139930672594512, Params: Sarsa Lambda: alph...    34
#        ID: 139930672608160, Params: Sarsa Lambda: alph...    40
#        ID: 139930672609456, Params: Sarsa Lambda: alph...    42
# ...                                                         ...
# 49     ID: 139930673099968, Params: Sarsa Lambda: alph...    29
#        ID: 139930673101264, Params: Sarsa Lambda: alph...    32
#        ID: 139930673102560, Params: Sarsa Lambda: alph...    48
#        ID: 139932055107040, Params: Sarsa Lambda: alph...    31
#        ID: 139932055107472, Params: Sarsa Lambda: alph...    30
#
# [1932 rows x 1 columns]

# %%
import pandas as pd
scatter = pd.concat([arrival_time.loc[(10)], travelling_time.loc[(10)]], axis=1, sort=False)
scatter.columns = ['arrival_time', 'travelling_time']
scatter
# Out:
#                                                            arrival_time  \
# sample agent
# 0      ID: 139930672591920, Params: Sarsa Lambda: alph...            30
#        ID: 139930672593216, Params: Sarsa Lambda: alph...            65
#        ID: 139930672594512, Params: Sarsa Lambda: alph...            42
#        ID: 139930672608160, Params: Sarsa Lambda: alph...            48
#        ID: 139930672609456, Params: Sarsa Lambda: alph...            62
# ...                                                                 ...
# 49     ID: 139930673099968, Params: Sarsa Lambda: alph...            29
#        ID: 139930673101264, Params: Sarsa Lambda: alph...            41
#        ID: 139930673102560, Params: Sarsa Lambda: alph...            70
#        ID: 139932055107040, Params: Sarsa Lambda: alph...            35
#        ID: 139932055107472, Params: Sarsa Lambda: alph...            42
#
#                                                            travelling_time
# sample agent
# 0      ID: 139930672591920, Params: Sarsa Lambda: alph...               30
#        ID: 139930672593216, Params: Sarsa Lambda: alph...               47
#        ID: 139930672594512, Params: Sarsa Lambda: alph...               34
#        ID: 139930672608160, Params: Sarsa Lambda: alph...               40
#        ID: 139930672609456, Params: Sarsa Lambda: alph...               42
# ...                                                                    ...
# 49     ID: 139930673099968, Params: Sarsa Lambda: alph...               29
#        ID: 139930673101264, Params: Sarsa Lambda: alph...               32
#        ID: 139930673102560, Params: Sarsa Lambda: alph...               48
#        ID: 139932055107040, Params: Sarsa Lambda: alph...               31
#        ID: 139932055107472, Params: Sarsa Lambda: alph...               30
#
# [1932 rows x 2 columns]

# %%
points = [
    tuple(row)
    for _, row in scatter.iterrows()
]
points[:10]
# Out:
# [(30, 30),
#  (65, 47),
#  (42, 34),
#  (48, 40),
#  (62, 42),
#  (44, 32),
#  (47, 45),
#  (56, 43),
#  (43, 41),
#  (74, 55)]

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
plt.scatter([p[0] for p in points], [p[1] for p in points])

# %%
results
# Out:
#        test  sample  step                                              agent  \
# 0         1       0     0  ID: 139930672647328, Params: Sarsa Lambda: alp...
# 1         1       0     0  ID: 139930673029616, Params: Sarsa Lambda: alp...
# 2         1       0     1  ID: 139930672647328, Params: Sarsa Lambda: alp...
# 3         1       0     1  ID: 139930672987728, Params: Sarsa Lambda: alp...
# 4         1       0     1  ID: 139930673029616, Params: Sarsa Lambda: alp...
# ...     ...     ...   ...                                                ...
# 85665    10      49    73  ID: 139930673014672, Params: Sarsa Lambda: alp...
# 85666    10      49    74  ID: 139930672987728, Params: Sarsa Lambda: alp...
# 85667    10      49    74  ID: 139930673014672, Params: Sarsa Lambda: alp...
# 85668    10      49    75  ID: 139930673014672, Params: Sarsa Lambda: alp...
# 85669    10      49    75  ID: 139930672987728, Params: Sarsa Lambda: alp...
#
#        return_sum  wins  time  distance
# 0              -1     0  0.25  0.000000
# 1              -1     0  0.25  0.565685
# 2              -1     0  0.25  0.400000
# 3              -1     0  0.25  0.400000
# 4              -1     0  0.25  0.565685
# ...           ...   ...   ...       ...
# 85665          -1     0  0.25  0.565685
# 85666          -1     0  0.25  0.400000
# 85667          -1     0  0.25  0.565685
# 85668          20     1  0.25  0.565685
# 85669          20     1  0.25  0.400000
#
# [1634781 rows x 8 columns]

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance'], axis=1).groupby(['test', 'sample', 'step'])
count = groupby.count()

# %%
density = count / 200
density.columns = ['density']
density
# Out:
#                   density
# test sample step
# 1    0      0       0.010
#             1       0.015
#             2       0.025
#             3       0.025
#             4       0.035
# ...                   ...
# 10   49     71      0.025
#             72      0.020
#             73      0.015
#             74      0.010
#             75      0.010
#
# [48951 rows x 1 columns]

# %%
flow = count.cumsum()['agent'].rolling(window=2).apply(lambda x: x.iloc[-1] - x.iloc[0])
flow
# Out:
# test  sample  step
# 1     0       0       NaN
#               1       3.0
#               2       5.0
#               3       5.0
#               4       7.0
#                      ...
# 10    49      71      5.0
#               72      4.0
#               73      3.0
#               74      2.0
#               75      2.0
# Name: agent, Length: 48951, dtype: float64

# %%
scatter = pd.concat([density.loc[(10, 49)], flow.loc[(10, 49)]], axis=1, sort=False)
scatter.columns = ['density', 'flow']
scatter
# Out:
#       density  flow
# step
# 0       0.020   4.0
# 1       0.035   7.0
# 2       0.035   7.0
# 3       0.035   7.0
# 4       0.040   8.0
# ...       ...   ...
# 71      0.025   5.0
# 72      0.020   4.0
# 73      0.015   3.0
# 74      0.010   2.0
# 75      0.010   2.0
#
# [76 rows x 2 columns]

# %%
points = [
    tuple(row)
    for _, row in scatter.iterrows()
]
points
# Out:
# [(0.02, 4.0),
#  (0.035, 7.0),
#  (0.035, 7.0),
#  (0.035, 7.0),
#  (0.04, 8.0),
#  (0.045, 9.0),
#  (0.05, 10.0),
#  (0.065, 13.0),
#  (0.07, 14.0),
#  (0.08, 16.0),
#  (0.095, 19.0),
#  (0.115, 23.0),
#  (0.12, 24.0),
#  (0.13, 26.0),
#  (0.135, 27.0),
#  (0.15, 30.0),
#  (0.155, 31.0),
#  (0.165, 33.0),
#  (0.175, 35.0),
#  (0.21, 42.0),
#  (0.215, 43.0),
#  (0.225, 45.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.23, 46.0),
#  (0.225, 45.0),
#  (0.225, 45.0),
#  (0.215, 43.0),
#  (0.215, 43.0),
#  (0.2, 40.0),
#  (0.2, 40.0),
#  (0.19, 38.0),
#  (0.19, 38.0),
#  (0.185, 37.0),
#  (0.185, 37.0),
#  (0.175, 35.0),
#  (0.17, 34.0),
#  (0.16, 32.0),
#  (0.15, 30.0),
#  (0.145, 29.0),
#  (0.145, 29.0),
#  (0.145, 29.0),
#  (0.135, 27.0),
#  (0.13, 26.0),
#  (0.13, 26.0),
#  (0.115, 23.0),
#  (0.115, 23.0),
#  (0.105, 21.0),
#  (0.1, 20.0),
#  (0.095, 19.0),
#  (0.09, 18.0),
#  (0.085, 17.0),
#  (0.08, 16.0),
#  (0.075, 15.0),
#  (0.07, 14.0),
#  (0.065, 13.0),
#  (0.065, 13.0),
#  (0.06, 12.0),
#  (0.055, 11.0),
#  (0.05, 10.0),
#  (0.045, 9.0),
#  (0.04, 8.0),
#  (0.04, 8.0),
#  (0.035, 7.0),
#  (0.035, 7.0),
#  (0.03, 6.0),
#  (0.025, 5.0),
#  (0.02, 4.0),
#  (0.015, 3.0),
#  (0.01, 2.0),
#  (0.01, 2.0)]

# %%
plt.plot(list(range(len(points))), [p[0] for p in points])

# %%
plt.scatter([p[0] for p in points], [p[1] for p in points])

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance', 'agent'], axis=1).groupby(['test', 'sample'])
arrival_time = groupby.max() * 0.25
arrival_time
# Out:
#               step
# test sample
# 1    0       30.00
#      1       30.25
#      2       30.25
#      3       30.25
#      4       30.25
# ...            ...
# 10   42      19.50
#      43      21.25
#      46      21.50
#      48      19.00
#      49      18.75
#
# [418 rows x 1 columns]
