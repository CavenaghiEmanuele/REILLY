# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

import reinforcement_learning as rl

# %%
env = rl.TextEnvironment(
    text="##########XXXXXX###\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "###  ##  #####  ###\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "#                 #\n" +
         "##########SSSSSS###",
    max_steps=100,
    neighbor=rl.TextNeighbor.MOORE,
    raw_state=True
)

# %%
single_train_session = rl.SingleTrainSession(env, start_step=40)

# %%
for _ in range(20):
    #"""
    agent = rl.SarsaLambdaAgent(
            alpha=0.1,
            epsilon=0.3,
            gamma=0.99,
            lambd=0.98,
            epsilon_decay=0.99,
            trace_type="replacing",
            feature_dims=2,
            num_tilings=4,
            tiles_size=[4,4],
        )
    """
    agent = rl.SarsaAgent(
            states=env.states,
            actions=env.actions,
            alpha=0.1,
            epsilon=0.3,
            gamma=0.99,
            epsilon_decay=0.99,
        )
    """
    single_train_session.add_agent(agent)

# %%
results = single_train_session.run(500, 50, 50)
results
# Out:
# 100%|██████████| 500/500 [05:22<00:00,  1.55it/s]
#        test  sample  step                                              agent  \
# 0         1       1     0  ID: 139912529870560, Params: Sarsa Lambda: alp...
# 1         1       1     1  ID: 139912529870560, Params: Sarsa Lambda: alp...
# 2         1       1     2  ID: 139912529870560, Params: Sarsa Lambda: alp...
# 3         1       1     3  ID: 139912529921072, Params: Sarsa Lambda: alp...
# 4         1       1     3  ID: 139912529870560, Params: Sarsa Lambda: alp...
# ...     ...     ...   ...                                                ...
# 21982    10      49   129  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21983    10      49   130  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21984    10      49   131  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21985    10      49   132  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21986    10      49   133  ID: 139912529919424, Params: Sarsa Lambda: alp...
#
#        return_sum  wins  time  distance
# 0              -1     0  0.25  0.400000
# 1              -1     0  0.25  0.400000
# 2              -1     0  0.25  0.400000
# 3              -1     0  0.25  0.565685
# 4              -1     0  0.25  0.400000
# ...           ...   ...   ...       ...
# 21982          -1     0  0.25  0.565685
# 21983          -1     0  0.25  0.400000
# 21984          -1     0  0.25  0.565685
# 21985          -1     0  0.25  0.565685
# 21986          -1     0  0.25  0.000000
#
# [342133 rows x 8 columns]

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance'], axis=1).groupby(['test', 'sample', 'agent'])
arrival_time = groupby.max()
travelling_time = arrival_time - groupby.min()

# %%
arrival_time
# Out:
#                                                                 step
# test sample agent
# 1    1      ID: 139912529867968, Params: Sarsa Lambda: alph...   136
#             ID: 139912529869264, Params: Sarsa Lambda: alph...   118
#             ID: 139912529870560, Params: Sarsa Lambda: alph...    99
#             ID: 139912529916832, Params: Sarsa Lambda: alph...   137
#             ID: 139912529918128, Params: Sarsa Lambda: alph...   120
# ...                                                              ...
# 10   49     ID: 139912529969648, Params: Sarsa Lambda: alph...   126
#             ID: 139912529970944, Params: Sarsa Lambda: alph...    47
#             ID: 139912529972240, Params: Sarsa Lambda: alph...    42
#             ID: 139913928812576, Params: Sarsa Lambda: alph...    99
#             ID: 139913928812864, Params: Sarsa Lambda: alph...   119
#
# [3940 rows x 1 columns]

# %%
travelling_time
# Out:
#                                                                 step
# test sample agent
# 1    1      ID: 139912529867968, Params: Sarsa Lambda: alph...    99
#             ID: 139912529869264, Params: Sarsa Lambda: alph...    99
#             ID: 139912529870560, Params: Sarsa Lambda: alph...    99
#             ID: 139912529916832, Params: Sarsa Lambda: alph...    99
#             ID: 139912529918128, Params: Sarsa Lambda: alph...    99
# ...                                                              ...
# 10   49     ID: 139912529969648, Params: Sarsa Lambda: alph...    99
#             ID: 139912529970944, Params: Sarsa Lambda: alph...    45
#             ID: 139912529972240, Params: Sarsa Lambda: alph...    31
#             ID: 139913928812576, Params: Sarsa Lambda: alph...    99
#             ID: 139913928812864, Params: Sarsa Lambda: alph...    99
#
# [3940 rows x 1 columns]

# %%
arrival_time.loc[(10)]
# Out:
#                                                            step
# sample agent
# 7      ID: 139912529867968, Params: Sarsa Lambda: alph...   103
#        ID: 139912529869264, Params: Sarsa Lambda: alph...    51
#        ID: 139912529870560, Params: Sarsa Lambda: alph...    69
#        ID: 139912529916832, Params: Sarsa Lambda: alph...    43
#        ID: 139912529918128, Params: Sarsa Lambda: alph...   103
# ...                                                         ...
# 49     ID: 139912529969648, Params: Sarsa Lambda: alph...   126
#        ID: 139912529970944, Params: Sarsa Lambda: alph...    47
#        ID: 139912529972240, Params: Sarsa Lambda: alph...    42
#        ID: 139913928812576, Params: Sarsa Lambda: alph...    99
#        ID: 139913928812864, Params: Sarsa Lambda: alph...   119
#
# [360 rows x 1 columns]

# %%
travelling_time.loc[(10)]
# Out:
#                                                            step
# sample agent
# 7      ID: 139912529867968, Params: Sarsa Lambda: alph...    74
#        ID: 139912529869264, Params: Sarsa Lambda: alph...    46
#        ID: 139912529870560, Params: Sarsa Lambda: alph...    33
#        ID: 139912529916832, Params: Sarsa Lambda: alph...    31
#        ID: 139912529918128, Params: Sarsa Lambda: alph...   100
# ...                                                         ...
# 49     ID: 139912529969648, Params: Sarsa Lambda: alph...    99
#        ID: 139912529970944, Params: Sarsa Lambda: alph...    45
#        ID: 139912529972240, Params: Sarsa Lambda: alph...    31
#        ID: 139913928812576, Params: Sarsa Lambda: alph...    99
#        ID: 139913928812864, Params: Sarsa Lambda: alph...    99
#
# [360 rows x 1 columns]

# %%
import pandas as pd
scatter = pd.concat([arrival_time.loc[(10)], travelling_time.loc[(10)]], axis=1, sort=False)
scatter.columns = ['arrival_time', 'travelling_time']
scatter
# Out:
#                                                            arrival_time  \
# sample agent
# 7      ID: 139912529867968, Params: Sarsa Lambda: alph...           103
#        ID: 139912529869264, Params: Sarsa Lambda: alph...            51
#        ID: 139912529870560, Params: Sarsa Lambda: alph...            69
#        ID: 139912529916832, Params: Sarsa Lambda: alph...            43
#        ID: 139912529918128, Params: Sarsa Lambda: alph...           103
# ...                                                                 ...
# 49     ID: 139912529969648, Params: Sarsa Lambda: alph...           126
#        ID: 139912529970944, Params: Sarsa Lambda: alph...            47
#        ID: 139912529972240, Params: Sarsa Lambda: alph...            42
#        ID: 139913928812576, Params: Sarsa Lambda: alph...            99
#        ID: 139913928812864, Params: Sarsa Lambda: alph...           119
#
#                                                            travelling_time
# sample agent
# 7      ID: 139912529867968, Params: Sarsa Lambda: alph...               74
#        ID: 139912529869264, Params: Sarsa Lambda: alph...               46
#        ID: 139912529870560, Params: Sarsa Lambda: alph...               33
#        ID: 139912529916832, Params: Sarsa Lambda: alph...               31
#        ID: 139912529918128, Params: Sarsa Lambda: alph...              100
# ...                                                                    ...
# 49     ID: 139912529969648, Params: Sarsa Lambda: alph...               99
#        ID: 139912529970944, Params: Sarsa Lambda: alph...               45
#        ID: 139912529972240, Params: Sarsa Lambda: alph...               31
#        ID: 139913928812576, Params: Sarsa Lambda: alph...               99
#        ID: 139913928812864, Params: Sarsa Lambda: alph...               99
#
# [360 rows x 2 columns]

# %%
points = [
    tuple(row)
    for _, row in scatter.iterrows()
]
points[:10]
# Out:
# [(103, 74),
#  (51, 46),
#  (69, 33),
#  (43, 31),
#  (103, 100),
#  (109, 99),
#  (83, 46),
#  (53, 53),
#  (45, 36),
#  (85, 76)]

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
plt.scatter([p[0] for p in points], [p[1] for p in points])

# %%
results
# Out:
#        test  sample  step                                              agent  \
# 0         1       1     0  ID: 139912529870560, Params: Sarsa Lambda: alp...
# 1         1       1     1  ID: 139912529870560, Params: Sarsa Lambda: alp...
# 2         1       1     2  ID: 139912529870560, Params: Sarsa Lambda: alp...
# 3         1       1     3  ID: 139912529921072, Params: Sarsa Lambda: alp...
# 4         1       1     3  ID: 139912529870560, Params: Sarsa Lambda: alp...
# ...     ...     ...   ...                                                ...
# 21982    10      49   129  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21983    10      49   130  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21984    10      49   131  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21985    10      49   132  ID: 139912529919424, Params: Sarsa Lambda: alp...
# 21986    10      49   133  ID: 139912529919424, Params: Sarsa Lambda: alp...
#
#        return_sum  wins  time  distance
# 0              -1     0  0.25  0.400000
# 1              -1     0  0.25  0.400000
# 2              -1     0  0.25  0.400000
# 3              -1     0  0.25  0.565685
# 4              -1     0  0.25  0.400000
# ...           ...   ...   ...       ...
# 21982          -1     0  0.25  0.565685
# 21983          -1     0  0.25  0.400000
# 21984          -1     0  0.25  0.565685
# 21985          -1     0  0.25  0.565685
# 21986          -1     0  0.25  0.000000
#
# [342133 rows x 8 columns]

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance'], axis=1).groupby(['test', 'sample', 'step'])
count = groupby.count()

# %%
density = count / 200
density.columns = ['density']
density
# Out:
#                   density
# test sample step
# 1    1      0       0.005
#             1       0.005
#             2       0.005
#             3       0.010
#             4       0.010
# ...                   ...
# 10   49     129     0.005
#             130     0.005
#             131     0.005
#             132     0.005
#             133     0.005
#
# [26755 rows x 1 columns]

# %%
flow = count.cumsum()['agent'].rolling(window=2).apply(lambda x: x.iloc[-1] - x.iloc[0])
flow
# Out:
# test  sample  step
# 1     1       0       NaN
#               1       1.0
#               2       1.0
#               3       2.0
#               4       2.0
#                      ...
# 10    49      129     1.0
#               130     1.0
#               131     1.0
#               132     1.0
#               133     1.0
# Name: agent, Length: 26755, dtype: float64

# %%
scatter = pd.concat([density.loc[(10, 49)], flow.loc[(10, 49)]], axis=1, sort=False)
scatter.columns = ['density', 'flow']
scatter
# Out:
#       density  flow
# step
# 0       0.015   3.0
# 1       0.015   3.0
# 2       0.020   4.0
# 3       0.020   4.0
# 4       0.020   4.0
# ...       ...   ...
# 129     0.005   1.0
# 130     0.005   1.0
# 131     0.005   1.0
# 132     0.005   1.0
# 133     0.005   1.0
#
# [134 rows x 2 columns]

# %%
points = [
    tuple(row)
    for _, row in scatter.iterrows()
]
points[:20]
# Out:
# [(0.015, 3.0),
#  (0.015, 3.0),
#  (0.02, 4.0),
#  (0.02, 4.0),
#  (0.02, 4.0),
#  (0.025, 5.0),
#  (0.025, 5.0),
#  (0.03, 6.0),
#  (0.035, 7.0),
#  (0.035, 7.0),
#  (0.035, 7.0),
#  (0.04, 8.0),
#  (0.04, 8.0),
#  (0.04, 8.0),
#  (0.045, 9.0),
#  (0.045, 9.0),
#  (0.045, 9.0),
#  (0.05, 10.0),
#  (0.05, 10.0),
#  (0.06, 12.0)]

# %%
plt.plot(list(range(len(points))), [p[0] for p in points])

# %%
plt.scatter([p[0] for p in points], [p[1] for p in points])

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance', 'agent'], axis=1).groupby(['test', 'sample'])
arrival_time = groupby.max() * 0.25
arrival_time
# Out:
#               step
# test sample
# 1    1       34.25
#      3       34.50
#      4       34.50
#      6       34.25
#      9       34.25
# ...            ...
# 10   29      32.25
#      31      32.50
#      35      34.50
#      45      32.50
#      49      33.25
#
# [197 rows x 1 columns]

# %%
groupby = results.drop(['return_sum', 'wins', 'step'], axis=1).groupby(['test', 'sample', 'agent'])
speed = groupby.sum()
speed['speed'] = speed['distance'] / speed['time']
speed = speed.drop(['distance', 'time'], axis=1).round(decimals=1)
speed
# Out:
#                                                                 speed
# test sample agent
# 1    1      ID: 139912529867968, Params: Sarsa Lambda: alph...    1.5
#             ID: 139912529869264, Params: Sarsa Lambda: alph...    1.4
#             ID: 139912529870560, Params: Sarsa Lambda: alph...    0.8
#             ID: 139912529916832, Params: Sarsa Lambda: alph...    1.3
#             ID: 139912529918128, Params: Sarsa Lambda: alph...    1.5
# ...                                                               ...
# 10   49     ID: 139912529969648, Params: Sarsa Lambda: alph...    0.2
#             ID: 139912529970944, Params: Sarsa Lambda: alph...    1.4
#             ID: 139912529972240, Params: Sarsa Lambda: alph...    2.2
#             ID: 139913928812576, Params: Sarsa Lambda: alph...    0.3
#             ID: 139913928812864, Params: Sarsa Lambda: alph...    0.5
#
# [3940 rows x 1 columns]

# %%
points = speed.loc[(10)]['speed'].value_counts().to_dict()
points = [
    (key, value)
    for key, value in points.items()
]
points[:10]
# Out:
# [(0.7, 50),
#  (2.0, 40),
#  (2.2, 34),
#  (0.6, 31),
#  (1.9, 23),
#  (1.8, 22),
#  (1.7, 18),
#  (2.1, 17),
#  (0.9, 16),
#  (1.6, 14)]

# %%
from datetime import datetime
plt.bar([p[0] for p in points], [p[1] for p in points], width=0.05, edgecolor="black")
plt.savefig(datetime.now().strftime("%Y%m%d_%H%M%S") + '_speed_bars.jpg')

# %%
groupby = results.drop(['return_sum', 'wins', 'time', 'distance', 'agent'], axis=1).groupby(['test', 'sample'])
wall_clock_time = groupby.max() * 0.25
wall_clock_time.columns = ['wall_clock_time']
print(wall_clock_time.loc[(1, 49)])
# Out:
# wall_clock_time    34.25
# Name: (1, 49), dtype: float64
